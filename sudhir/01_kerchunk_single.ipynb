# %% [markdown]
# # Kerchunk the AORC-OWP NetCDF files

# %%
import fsspec
import xarray as xr
import ujson   # fast json
from kerchunk.hdf import SingleHdf5ToZarr 
from kerchunk.combine import MultiZarrToZarr
from pathlib import Path

# %%
fs_read = fsspec.filesystem('s3', requester_pays=True)

# %%
fs_write = fsspec.filesystem('s3', anon=False)

# %%
nc_files = fs_read.glob('s3://esip-qhub/noaa/my_ncfiles/200002/*.nc4') 

len(nc_files)
# Out:
# 387

# %%
import os
import sys
sys.path.append(os.path.join(os.environ['HOME'],'shared','users','lib'))
import ebdpy as ebd

profile = 'esip-qhub'
region = 'us-west-2'
endpoint = f's3.{region}.amazonaws.com'
ebd.set_credentials(profile=profile, region=region, endpoint=endpoint)
worker_max = 10
client,cluster = ebd.start_dask_cluster(profile=profile, worker_max=worker_max, 
                                      region=region, use_existing_cluster=True,
                                      adaptive_scaling=False, wait_for_cluster=False, 
                                      worker_profile='Small Worker', 
                                      propagate_env=True)
# Out:
# Region: us-west-2
# No Cluster running.
# Starting new cluster.
# {}
# Setting Cluster Environment Variable AWS_DEFAULT_REGION us-west-2
# Setting Fixed Scaling workers=10
# Reconnect client to clear cache
# client.dashboard_link (for new browser tab/window or dashboard searchbar in Jupyterhub):
# https://nebari.esipfed.org/gateway/clusters/dev.afae234cd3e54864aeaefb6ef8808669/status
# Propagating environment variables to workers
# Using environment: users/users-pangeo

# %%
json_dir = 's3://esip-qhub/noaa/AORC/jsons'

# %%
nc_files[0]
# Out:
# 'esip-qhub/noaa/my_ncfiles/200002/AORC-OWP_2000020100z.nc4'

# %%
#cluster.close()

# %%
def gen_json(u):
    with fs_read.open(u, **so) as infile:
        h5chunks = SingleHdf5ToZarr(infile, u, inline_threshold=300)
        fstem = Path(u).stem 
        outf = f'{json_dir}/{fstem}.json'
        print(outf)
        with fs_write.open(outf, 'wb') as f:
            f.write(ujson.dumps(h5chunks.translate()).encode());

# %%
so = dict(mode='rb', requester_pays=True, default_fill_cache=False, default_cache_type='first')

# %% [markdown]
# #### Test one file

# %%
# %%time 
gen_json(nc_files[0])
# Out:
# s3://esip-qhub/noaa/AORC/jsons/AORC-OWP_2000020100z.json
# CPU times: user 592 ms, sys: 117 ms, total: 709 ms
# Wall time: 1.56 s

# %%
single_json = 's3://esip-qhub/noaa/AORC/jsons/AORC-OWP_2000020100z.json'

# %%
# %%time
fs = fsspec.filesystem("reference", fo=single_json, ref_storage_args={'skip_instance_cache':True},
                       remote_protocol='s3', remote_options={'requester_pays':True})
# Out:
# CPU times: user 97.2 ms, sys: 25.6 ms, total: 123 ms
# Wall time: 353 ms

# %%
fs.ls('PRES_surface')

# %%
m = fs.get_mapper("")
ds = xr.open_dataset(m, engine="zarr", backend_kwargs={'consolidated':False}, chunks={})

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 1, latitude: 4201, longitude: 8401)
# Coordinates:
#   * latitude             (latitude) float64 20.0 20.01 20.02 ... 54.99 55.0
#   * longitude            (longitude) float64 -130.0 -130.0 ... -60.01 -60.0
#   * time                 (time) datetime64[ns] 2000-02-01
# Data variables:
#     APCP_surface         (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     DLWRF_surface        (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     DSWRF_surface        (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     PRES_surface         (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     SPFH_2maboveground   (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     TMP_2maboveground    (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     UGRD_10maboveground  (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>
#     VGRD_10maboveground  (time, latitude, longitude) float32 dask.array<chunksize=(1, 1024, 2048), meta=np.ndarray>

# %% [markdown]
# #### Use Dask bag to compute the JSONs in parallel

# %%
import dask.bag as db

# %%
b = db.from_sequence(nc_files, npartitions=worker_max)

# %%
b1 = b.map(gen_json)

# %%
# %%time
_ = b1.compute(retries=10)
# Out:
# CPU times: user 152 ms, sys: 39.6 ms, total: 192 ms
# Wall time: 2min 10s

# %%
json_list = fs_write.glob(f'{json_dir}/*.json')

# %%
print(len(json_list))
# Out:
# 387
# Exception in callback None()
# handle: <Handle cancelled>
# Traceback (most recent call last):
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/tornado/iostream.py", line 1389, in _do_ssl_handshake
#     self.socket.do_handshake()
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/ssl.py", line 1342, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:997)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 206, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/tornado/iostream.py", line 698, in _handle_events
#     self._handle_read()
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/tornado/iostream.py", line 1476, in _handle_read
#     self._do_ssl_handshake()
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/tornado/iostream.py", line 1407, in _do_ssl_handshake
#     return self.close(exc_info=err)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/tornado/iostream.py", line 613, in close
#     self._signal_closed()
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/tornado/iostream.py", line 643, in _signal_closed
#     self._ssl_connect_future.exception()
# asyncio.exceptions.CancelledError
# 2023-03-29 09:20:47,309 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# /home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/dask_gateway/client.py:1014: RuntimeWarning: coroutine 'rpc.close_rpc' was never awaited
#   self.scheduler_comm.close_rpc()
# 2023-03-29 09:39:44,679 - distributed.client - ERROR - Exception raised while shutting down cluster dev.afae234cd3e54864aeaefb6ef8808669
# Traceback (most recent call last):
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/dask_gateway/client.py", line 993, in _stop_internal
#     await self.gateway._stop_cluster(self.name)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/dask_gateway/client.py", line 654, in _stop_cluster
#     await self._request("DELETE", url)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/dask_gateway/client.py", line 397, in _request
#     resp = await session.request(method, url, json=json, **self._request_kwargs)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/aiohttp/client.py", line 536, in _request
#     conn = await self._connector.connect(
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/aiohttp/connector.py", line 540, in connect
#     proto = await self._create_connection(req, traces, timeout)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/aiohttp/connector.py", line 901, in _create_connection
#     _, proto = await self._create_direct_connection(req, traces, timeout)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/aiohttp/connector.py", line 1152, in _create_direct_connection
#     hosts = await asyncio.shield(host_resolved)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/aiohttp/connector.py", line 874, in _resolve_host
#     addrs = await self._resolver.resolve(host, port, family=self._family)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/site-packages/aiohttp/resolver.py", line 33, in resolve
#     infos = await self._loop.getaddrinfo(
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/asyncio/base_events.py", line 863, in getaddrinfo
#     return await self.run_in_executor(
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/asyncio/base_events.py", line 821, in run_in_executor
#     executor.submit(func, *args), loop=self)
#   File "/home/conda/users/def60d898570988b3144fa6932cb0087c18afd4f3261c08887f846a32495ba96-20230328-131936-847877-164-pangeo/lib/python3.10/concurrent/futures/thread.py", line 167, in submit
#     raise RuntimeError('cannot schedule new futures after shutdown')
# RuntimeError: cannot schedule new futures after shutdown
